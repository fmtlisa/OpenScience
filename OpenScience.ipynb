# %% [markdown]
# ## Pie chart

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt

# %%
labels = 'R GROUP To start, please select a group. There is no right or wrong answer.','R CONTENT', 'R Imagine you are a lecturer at a famous university.', 'R What culture do you identify with the most?', 'R Were you familiar with this topic before hearing the podcast?', 'R What is your academic background?','R sex','R Does this topic interest you?', 'R Are you currently a student in a parisian institute?','RWhat is your current level of education?', 'unknown factors'
sizes = [0.1369, 14.0625, 31.9225, 0.2809, 11.3569, 0.0441, 7.8961, 0.9409, 0.2116, 0.0004, 33.1742]

plt.figure(figsize=(15,15))
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True)
plt.legend( labels, loc="best")
plt.title('To what degree has the speaker interested you in the topic discussed in the audio? partial correlation of multiple factors')

plt.axis('equal')
plt.show()

# %%
labels = 'R GROUP To start, please select a group. There is no right or wrong answer.','R CONTENT', 'R Imagine you are a lecturer at a famous university.', 'R What culture do you identify with the most?', 'R Were you familiar with this topic before hearing the podcast?', 'R What is your academic background?','R sex','R Does this topic interest you?', 'R Are you currently a student in a parisian institute?','RWhat is your current level of education?', 'unknown factors'
sizes = [0.2704, 19.0096, 0.0676, 11.0889, 12.8164, 16.5649, 0.5929, 3.4596, 1.2769, 3.61, 31.2428]

plt.figure(figsize=(15,15))
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True)
plt.legend( labels, loc="best")
plt.title('How would you categorize the speakers competence in the topic discussed on the audio? partial correlation of multiple factors')

plt.axis('equal')
plt.show()

# %%
labels = 'R GROUP To start, please select a group. There is no right or wrong answer.','R CONTENT', 'R Imagine you are a lecturer at a famous university.', 'R What culture do you identify with the most?', 'R Were you familiar with this topic before hearing the podcast?', 'R What is your academic background?','R sex','R Does this topic interest you?', 'R Are you currently a student in a parisian institute?','RWhat is your current level of education?', 'unknown factors'
sizes = [2.0449, 5.8081, 24.7009, 3.1329, 4.6656, 0.1685159, 0.09, 2.2201, 0.1296 , 0.1296, 56.909781]

plt.figure(figsize=(16,16))
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True)
plt.legend( labels, loc="best")
plt.title('You are the founder of a tech start-up in Silicon Valley. partial correlation of multiple factors')

plt.axis('equal')
plt.show()

# %%
labels = 'R GROUP To start, please select a group. There is no right or wrong answer.','R CONTENT', 'R Imagine you are a lecturer at a famous university.', 'R What culture do you identify with the most?', 'R Were you familiar with this topic before hearing the podcast?', 'R What is your academic background?','R sex','R Does this topic interest you?', 'R Are you currently a student in a parisian institute?','RWhat is your current level of education?', 'unknown factors'
sizes = [0.1024 , 0.7569, 3.0976 , 0.0729 , 0.25, 0.9025, 0.2209, 7.4529, 8.5264, 24.7009, 53.9166]

plt.figure(figsize=(16,16))
plt.pie(sizes, labels=labels,
autopct='%1.1f%%', shadow=True)
plt.legend( labels, loc="best")
plt.title('Imagine you are a lecturer at a famous university. partial correlation of multiple factors')

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Thematic analysis

# %% [markdown]
# Here is a small reminder of the datas we gathered. We will be focusing on the column called:
# "The person you heard presenting is going to an interview into the university you're studying at to become professor. If you know you're taking their course next semester, would you like them to be hired and why ? "

# %%
import pandas as pd
qu=pd.read_csv("Questionnaire.csv", sep=";", encoding='cp1252')
qu.head(5)
# Out:
#             Timestamp  \
# 0  12/8/2020 10:12:49
# 1    12/08/2020 10:43
# 2  12/8/2020 16:23:31
# 3  12/8/2020 21:37:54
# 4  12/9/2020 10:19:36
#
#   GROUP To start, please select a group. There is no right or wrong answer.  \
# 0                                            Group B
# 1                                            Group A
# 2                                            Group A
# 3                                            Group A
# 4                                            Group A
#
#    R GROUP To start, please select a group. There is no right or wrong answer.  \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How much of the content do you feel you understood?  \
# 0                                                NaN
# ...

# %%
qu = qu.rename({'R GROUP To start, please select a group. There is no right or wrong answer.': 'Gender of the speaker (r) ', 'How much of the content do you feel you understood?': 'Feeling about the understanding ', 'R CONTENT':'Understood content', 'R CONTENT':'Understood content',"R Imagine you are a lecturer at a famous university. For YOUR STUDENTS' final assignment, you decide to ask them to produce a science communication podcast. Your student presents you WITH the recording you JUST heard. WHAT grade would you give them, knowing that A is the best grade, and E is the worst one?":'Audio as coming from a student (R)', 'R Were you familiar with this topic before hearing the podcast?':'Knowing the topic before (R)', 'R Does this topic interest you?':'Interest of the participant in the subject (R)', 'Below is a linear scale ranging from 1 (Not at all), to 7 (Very much). To what degree has the speaker interested you in the topic discussed in the audio?':'Interest created by the speaker’s presence', 'Below is a linear scale ranging from 1 (not competent) to 7 (extremely competent). How would you categorize the speakers competence in the topic discussed on the audio? ':'Competence evaluation', "Below is a linear scale ranging from 1 (not likely) to 7 (highly likely). You are the founder of a tech start-up in Silicon Valley. You have advertised 2 open positions in your physics team on LinkedIn. In the advertisement you state that the individuals interested in applying for a job should email a self-produced, educational, and entertaining physics video. If you had received an email with the audio you heard previously, how likely is it for you to invite the speaker to an interview?":'Audio as coming from a professional ', 'Age':'age', 'R Are you currently a student in a parisian institute?':'is the participant a student in paris  (r)', 'RWhat is your current level of education?':'Level of education (R )', 'R sex':'Gender of the participant (R )', 'Rdesirability':'Score on the Desirability Scale', 'R What is your academic background?':'Academic background (R )', 'R What culture do you identify with the most?':'Culture (R )'}, axis='columns')

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(qu.corr(), annot=True, cmap='RdBu_r', center=0, vmin=-1, vmax=1,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We will now focus on the thematic analysis. We started by dividing the answers in 6 groups:
# - The participants from group A answering "Yes": ayes
# - The participants from group A answering "No": ano
# - The participants from group A not giving a clear answer: adontknow
# - The participants from group B answering "Yes": byes
# - The participants from group B answering "No": bno
# - The participants from group B not giving a clear answer: bdontknow
#
# We will count the amount of appearances of each word. Jupyter lab will provide us a list of those words, and the frequency of their appearance.
# We will next use Vizzlo, a free online software, to create visual wordclouds, making the most important repeated words appear more clearly.

# %% [markdown]
# Here is the ayes group.

# %%
from collections import defaultdict as dd
from collections import Counter

# %%
import nltk
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lisaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
ayes="not really interested but for sake of the study I would say yes for interest in learning new things and the speaker sounded good Yes so he can explain it to me with images Although I was not interested by the topic I can say that his voice sounds calm reassuring and interesting Although I was not interested by the topic I can say that his voice sounds calm reassuring and interesting I'm torn because they seem to master the topic but it just wasn't very engaging for me on a personal level and I was easily distracted I would like them to be hired though Yes the subject was well explained even if the podcast was a bit short and the person doesn't speak to rapidly thus it's easy to follow what he is saying However he maybe speaks even too slowly it would be perfect for an online course slow for when he explains difficult things and well articulated to be able to still understand in x2 speed I think the person did a pretty good job Considering that physics is a very very visual subject a podcast is really difficult to make especially on mechanics the way he explained it was not very mundane however I think he lacked some more examples that could have made this topic more relevant and relateable I've seen what he's talking about so I understand but really there was almost no context to the actual problem of the spaghetti splitting up into 3 pieces it is difficult to evaluate it if I do not know your professional experience but according to what I have heard and being a lecturer on the subject I think that I could do a good job as a teacher I would hire him he sounds very competent when he speaks I think so but I think that his teaching experience should also be reviewed it cannot be determined just by listening to his lecture Yes he sounds like a teacher who knows or at least prepares his subject matter very well ".lower()
ayes2=ayes.split(' ')
cnt = Counter()
for word in ayes2:
    if word not in stop_words:
        cnt[word] += 1
    else:
        pass
cnt

ayes3=Counter(cnt).most_common()
ayes3
# Out:
# [('think', 5),
#  ('would', 4),
#  ('yes', 4),
#  ('topic', 4),
#  ('sounds', 4),
#  ('subject', 4),
#  ('really', 3),
#  ('interested', 3),
#  ('say', 3),
#  ('good', 3),
#  ('well', 3),
#  ('difficult', 3),
#  ('things', 2),
#  ('although', 2),
#  ('voice', 2),
#  ('calm', 2),
#  ('reassuring', 2),
#  ('interesting', 2),
#  ('like', 2),
#  ('explained', 2),
#  ('even', 2),
#  ('podcast', 2),
#  ('person', 2),
#  ('however', 2),
#  ('speaks', 2),
#  ('understand', 2),
#  ('job', 2),
#  ('could', 2),
#  ('experience', 2),
#  ('teacher', 2),
#  ('sake', 1),
#  ('study', 1),
#  ('interest', 1),
#  ('learning', 1),
#  ('new', 1),
#  ('speaker', 1),
#  ('sounded', 1),
#  ('explain', 1),
#  ('images', 1),
#  ("i'm", 1),
#  ('torn', 1),
#  ('seem', 1),
#  ('master', 1),
#  ('engaging', 1),
#  ('personal', 1),
#  ('level', 1),
#  ('easily', 1),
#  ('distracted', 1),
#  ('hired', 1),
#  ('though', 1),
#  ('bit', 1),
#  ('short', 1),
#  ('speak', 1),
#  ('rapidly', 1),
#  ('thus', 1),
# ...

# %%
len(ayes)
# Out:
# 1839

# %%
wordcloud = WordCloud().generate(str(ayes3))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Here is the ano group.

# %%
ano="No No the person was so monotone I couldn't follow along He lost me after few minutes ".lower()
ano2=ano.split(' ')

cnt = Counter()
for word in ano2:
    if word not in stop_words:
        cnt[word] += 1
    else:
        pass
cnt

ano3=Counter(cnt).most_common()
ano3
# Out:
# [('person', 1),
#  ('monotone', 1),
#  ('follow', 1),
#  ('along', 1),
#  ('lost', 1),
#  ('minutes', 1),
#  ('', 1)]

# %%
len(ano)
# Out:
# 86

# %%
wordcloud = WordCloud().generate(str(ano3))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Here is the adontknow group.

# %%
adontknow="I don't know His explanation seems scientifically correct but I would need a drawing or see it written down to truly understand it If he doesn't do that I don't think he'll be a good teacher for me".lower()
adontknow2=adontknow.split(' ')
cnt = Counter()
for word in adontknow2:
    if word not in stop_words:
        cnt[word] += 1
    else:
        pass
cnt

adontknow3=Counter(cnt).most_common()
adontknow3
# Out:
# [('know', 1),
#  ('explanation', 1),
#  ('seems', 1),
#  ('scientifically', 1),
#  ('correct', 1),
#  ('would', 1),
#  ('need', 1),
#  ('drawing', 1),
#  ('see', 1),
#  ('written', 1),
#  ('truly', 1),
#  ('understand', 1),
#  ('think', 1),
#  ("he'll", 1),
#  ('good', 1),
#  ('teacher', 1)]

# %%
len(adontknow)
# Out:
# 197

# %%
wordcloud = WordCloud().generate(str(adontknow3))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Here is the byes group.

# %%
byes="it depends what they're teaching it was a very good podcast but it had a lot of specific terms that were not explained so I wouldn't pick this person for a science communication class but definitely for a physics class I really can't be sure a podcast is so much different than anything with visual support but to me it seems as though the person did not use enough visual imagery for me to understand well what was happening and did not adapt to the means of communication They might be better at courses with slides but am not satisfied enough with this podcast Yes I think the explanations were clear maybe lacking a bit enthusiasm but I guess it could have been due to the fact that we only had an audio and no visual that makes it more difficult to remain concentrated on what is said explanation step by step is clear for someone who has a very basic understanding of how forces work in physics  Of course she does she sounds very safe and confident when she talks about it she would surely do very well in a classroom".lower()
byes2=byes.split(' ')

cnt = Counter()
for word in byes2:
    if word not in stop_words:
        cnt[word] += 1
    else:
        pass
cnt

byes3=Counter(cnt).most_common()
byes3
# Out:
# [('podcast', 3),
#  ('visual', 3),
#  ('person', 2),
#  ('communication', 2),
#  ('class', 2),
#  ('physics', 2),
#  ('enough', 2),
#  ('well', 2),
#  ('clear', 2),
#  ('step', 2),
#  ('depends', 1),
#  ("they're", 1),
#  ('teaching', 1),
#  ('good', 1),
#  ('lot', 1),
#  ('specific', 1),
#  ('terms', 1),
#  ('explained', 1),
#  ('pick', 1),
#  ('science', 1),
#  ('definitely', 1),
#  ('really', 1),
#  ("can't", 1),
#  ('sure', 1),
#  ('much', 1),
#  ('different', 1),
#  ('anything', 1),
#  ('support', 1),
#  ('seems', 1),
#  ('though', 1),
#  ('use', 1),
#  ('imagery', 1),
#  ('understand', 1),
#  ('happening', 1),
#  ('adapt', 1),
#  ('means', 1),
#  ('might', 1),
#  ('better', 1),
#  ('courses', 1),
#  ('slides', 1),
#  ('satisfied', 1),
#  ('yes', 1),
#  ('think', 1),
#  ('explanations', 1),
#  ('maybe', 1),
#  ('lacking', 1),
#  ('bit', 1),
#  ('enthusiasm', 1),
#  ('guess', 1),
#  ('could', 1),
#  ('due', 1),
#  ('fact', 1),
#  ('audio', 1),
#  ('makes', 1),
# ...

# %%
len(byes)
# Out:
# 1024

# %%
wordcloud = WordCloud().generate(str(byes3))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Here is the bno group.

# %%
bno="I don't know His explanation seems scientifically correct  but I would need a drawing or see it written down to truly understand it If he doesn't do that I don't think he'll be a good teacher for me Sleepy speech style".lower()
bno2=bno.split(' ')
cnt = Counter()
for word in bno2:
    if word not in stop_words:
        cnt[word] += 1
    else:
        pass
cnt

bno3=Counter(cnt).most_common()
bno3
# Out:
# [('know', 1),
#  ('explanation', 1),
#  ('seems', 1),
#  ('scientifically', 1),
#  ('correct', 1),
#  ('', 1),
#  ('would', 1),
#  ('need', 1),
#  ('drawing', 1),
#  ('see', 1),
#  ('written', 1),
#  ('truly', 1),
#  ('understand', 1),
#  ('think', 1),
#  ("he'll", 1),
#  ('good', 1),
#  ('teacher', 1),
#  ('sleepy', 1),
#  ('speech', 1),
#  ('style', 1)]

# %%
len(bno)
# Out:
# 218

# %%
wordcloud = WordCloud().generate(str(bno3))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Here is the bdontknow group.

# %%
bdontknow="Two minutes is quite a short time to condense an introduction motivation along with what and how of what is a pretty dense topic Good job at that If it were allowed I'd need to however listen to the audio once more since my short-term memory is quite bad I really can't be sure a podcast is so much different than anything with visual support but to me it seems as though the person did not use enough visual imagery for me to understand well what was happening and did not adapt to the means of communication They might be better at courses with slides but am not satisfied enough with this podcast Hard to say from a 2 min audio If she speaks less monotonously and uses visualizations during her lectures she's hired maybe because it's a new point of view It depends on the subject the voice is a little bit monotonous On the other hand the fact that I have no knowledge whatsoever on why does a spaghetti break in multiple pieces I may have more difficulties understanding the course In my opinion the podcast isn't enough and it would've been preferable to have a video to watch because visualization can bring better understanding Maybe While the audio was clear and easy to understand the info was presented in a very boring manner that didn't make me want to listen and focus Insufficient evidence It clearly depends on the person's willingness to improve his her science communication skills and make the content engaging Unfortunately I grew up in an education system that places emphasis on rote learning and grades and less on understanding and practical application Many of my classmates relied on their ability to learn by themselves If the person provides good notes text books and is kind empathetic on the grading this counted way more for meus in school than the teacher's ability to teach be understood".lower()
bdontknow2=bdontknow.split(' ')
cnt = Counter()
for word in bdontknow2:
    if word not in stop_words:
        cnt[word] += 1
    else:
        pass
cnt

vi=Counter(cnt).most_common()
vi
# Out:
# [('audio', 3),
#  ('podcast', 3),
#  ('enough', 3),
#  ('understanding', 3),
#  ('quite', 2),
#  ('good', 2),
#  ('listen', 2),
#  ('visual', 2),
#  ('person', 2),
#  ('understand', 2),
#  ('communication', 2),
#  ('better', 2),
#  ('less', 2),
#  ('maybe', 2),
#  ('depends', 2),
#  ('make', 2),
#  ('ability', 2),
#  ('two', 1),
#  ('minutes', 1),
#  ('short', 1),
#  ('time', 1),
#  ('condense', 1),
#  ('introduction', 1),
#  ('motivation', 1),
#  ('along', 1),
#  ('pretty', 1),
#  ('dense', 1),
#  ('topic', 1),
#  ('job', 1),
#  ('allowed', 1),
#  ("i'd", 1),
#  ('need', 1),
#  ('however', 1),
#  ('since', 1),
#  ('short-term', 1),
#  ('memory', 1),
#  ('bad', 1),
#  ('really', 1),
#  ("can't", 1),
#  ('sure', 1),
#  ('much', 1),
#  ('different', 1),
#  ('anything', 1),
#  ('support', 1),
#  ('seems', 1),
#  ('though', 1),
#  ('use', 1),
#  ('imagery', 1),
#  ('well', 1),
#  ('happening', 1),
#  ('adapt', 1),
#  ('means', 1),
#  ('might', 1),
#  ('courses', 1),
#  ('slides', 1),
# ...

# %%
len(bdontknow)
# Out:
# 1820

# %% [markdown]
# ![image.png](attachment:b40395bc-1b05-4cef-8573-d72b4c47af6e.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from sklearn.datasets import make_blobs, make_classification
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier

import numpy as np
import pandas as pd
import math

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

import nltk
nltk.download('wordnet')
from nltk.stem import PorterStemmer, WordNetLemmatizer

from wordcloud import WordCloud
from stop_words import get_stop_words
import string
import re
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lisaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
ayes="not really interested but for sake of the study I would say yes for interest in learning new things and the speaker sounded good Yes so he can explain it to me with images Although I was not interested by the topic I can say that his voice sounds calm reassuring and interesting Although I was not interested by the topic I can say that his voice sounds calm reassuring and interesting I'm torn because they seem to master the topic but it just wasn't very engaging for me on a personal level and I was easily distracted I would like them to be hired though Yes the subject was well explained even if the podcast was a bit short and the person doesn't speak to rapidly thus it's easy to follow what he is saying However he maybe speaks even too slowly it would be perfect for an online course slow for when he explains difficult things and well articulated to be able to still understand in x2 speed I think the person did a pretty good job Considering that physics is a very very visual subject a podcast is really difficult to make especially on mechanics the way he explained it was not very mundane however I think he lacked some more examples that could have made this topic more relevant and relateable I've seen what he's talking about so I understand but really there was almost no context to the actual problem of the spaghetti splitting up into 3 pieces it is difficult to evaluate it if I do not know your professional experience but according to what I have heard and being a lecturer on the subject I think that I could do a good job as a teacher I would hire him he sounds very competent when he speaks I think so but I think that his teaching experience should also be reviewed it cannot be determined just by listening to his lecture Yes he sounds like a teacher who knows or at least prepares his subject matter very well ".lower()
wordcloud = WordCloud().generate(str(ayes))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
porter= PorterStemmer()
for w in word_tokenize(ayes) :
    if len(w) > 4: 
        print(porter.stem(w))
    else: 
        pass
# Out:
# realli
# interest
# studi
# would
# interest
# learn
# thing
# speaker
# sound
# explain
# imag
# although
# interest
# topic
# voic
# sound
# reassur
# interest
# although
# interest
# topic
# voic
# sound
# reassur
# interest
# becaus
# master
# topic
# engag
# person
# level
# easili
# distract
# would
# hire
# though
# subject
# explain
# podcast
# short
# person
# speak
# rapidli
# follow
# say
# howev
# mayb
# speak
# slowli
# would
# perfect
# onlin
# cours
# explain
# difficult
# thing
# articul
# still
# understand
# speed
# think
# person
# pretti
# consid
# physic
# visual
# subject
# podcast
# realli
# difficult
# especi
# mechan
# explain
# mundan
# howev
# think
# lack
# exampl
# could
# topic
# relev
# relat
# talk
# about
# understand
# realli
# there
# almost
# context
# actual
# problem
# spaghetti
# split
# piec
# difficult
# evalu
# profession
# experi
# accord
# heard
# be
# lectur
# subject
# think
# could
# teacher
# would
# sound
# compet
# speak
# think
# ...

# %%
ano="No No the person was so monotone I couldn't follow along He lost me after few minutes ".lower()
wordcloud = WordCloud().generate(str(ano))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
porter= PorterStemmer()
for w in word_tokenize(ano) :
    if len(w) > 4: 
        print(porter.stem(w))
    else: 
        pass
# Out:
# person
# monoton
# could
# follow
# along
# after
# minut

# %%
adontknow="I don't know His explanation seems scientifically correct but I would need a drawing or see it written down to truly understand it If he doesn't do that I don't think he'll be a good teacher for me".lower()
wordcloud = WordCloud().generate(str(adontknow))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
porter= PorterStemmer()
for w in word_tokenize(adontknow) :
    if len(w) > 4: 
        print(porter.stem(w))
    else: 
        pass
# Out:
# explan
# seem
# scientif
# correct
# would
# draw
# written
# truli
# understand
# think
# teacher

# %%
byes="it depends what they're teaching it was a very good podcast but it had a lot of specific terms that were not explained so I wouldn't pick this person for a science communication class but definitely for a physics class I really can't be sure a podcast is so much different than anything with visual support but to me it seems as though the person did not use enough visual imagery for me to understand well what was happening and did not adapt to the means of communication They might be better at courses with slides but am not satisfied enough with this podcast Yes I think the explanations were clear maybe lacking a bit enthusiasm but I guess it could have been due to the fact that we only had an audio and no visual that makes it more difficult to remain concentrated on what is said explanation step by step is clear for someone who has a very basic understanding of how forces work in physics  Of course she does she sounds very safe and confident when she talks about it she would surely do very well in a classroom".lower()

wordcloud = WordCloud().generate(str(byes))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
porter= PorterStemmer()
for w in word_tokenize(byes) :
    if len(w) > 4: 
        print(porter.stem(w))
    else: 
        pass
# Out:
# depend
# teach
# podcast
# specif
# term
# explain
# would
# person
# scienc
# commun
# class
# definit
# physic
# class
# realli
# podcast
# differ
# anyth
# visual
# support
# seem
# though
# person
# enough
# visual
# imageri
# understand
# happen
# adapt
# mean
# commun
# might
# better
# cours
# slide
# satisfi
# enough
# podcast
# think
# explan
# clear
# mayb
# lack
# enthusiasm
# guess
# could
# audio
# visual
# make
# difficult
# remain
# concentr
# explan
# clear
# someon
# basic
# understand
# forc
# physic
# cours
# sound
# confid
# talk
# about
# would
# sure
# classroom

# %%
bno="I don't know His explanation seems scientifically correct  but I would need a drawing or see it written down to truly understand it If he doesn't do that I don't think he'll be a good teacher for me Sleepy speech style".lower()

wordcloud = WordCloud().generate(str(bno))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
porter= PorterStemmer()
for w in word_tokenize(bno) :
    if len(w) > 4: 
        print(porter.stem(w))
    else: 
        pass
# Out:
# explan
# seem
# scientif
# correct
# would
# draw
# written
# truli
# understand
# think
# teacher
# sleepi
# speech
# style

# %%
bdontknow="Two minutes is quite a short time to condense an introduction motivation along with what and how of what is a pretty dense topic Good job at that If it were allowed I'd need to however listen to the audio once more since my short-term memory is quite bad I really can't be sure a podcast is so much different than anything with visual support but to me it seems as though the person did not use enough visual imagery for me to understand well what was happening and did not adapt to the means of communication They might be better at courses with slides but am not satisfied enough with this podcast Hard to say from a 2 min audio If she speaks less monotonously and uses visualizations during her lectures she's hired maybe because it's a new point of view It depends on the subject the voice is a little bit monotonous On the other hand the fact that I have no knowledge whatsoever on why does a spaghetti break in multiple pieces I may have more difficulties understanding the course In my opinion the podcast isn't enough and it would've been preferable to have a video to watch because visualization can bring better understanding Maybe While the audio was clear and easy to understand the info was presented in a very boring manner that didn't make me want to listen and focus Insufficient evidence It clearly depends on the person's willingness to improve his her science communication skills and make the content engaging Unfortunately I grew up in an education system that places emphasis on rote learning and grades and less on understanding and practical application Many of my classmates relied on their ability to learn by themselves If the person provides good notes text books and is kind empathetic on the grading this counted way more for meus in school than the teacher's ability to teach be understood".lower()
wordcloud = WordCloud().generate(str(bdontknow))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
porter= PorterStemmer()
for w in word_tokenize(bdontknow) :
    if len(w) > 4: 
        print(porter.stem(w))
    else: 
        pass
# Out:
# minut
# quit
# short
# condens
# introduct
# motiv
# along
# pretti
# dens
# topic
# allow
# howev
# listen
# audio
# sinc
# short-term
# memori
# quit
# realli
# podcast
# differ
# anyth
# visual
# support
# seem
# though
# person
# enough
# visual
# imageri
# understand
# happen
# adapt
# mean
# commun
# might
# better
# cours
# slide
# satisfi
# enough
# podcast
# audio
# speak
# monoton
# visual
# dure
# lectur
# hire
# mayb
# becaus
# point
# depend
# subject
# voic
# littl
# monoton
# other
# knowledg
# whatsoev
# spaghetti
# break
# multipl
# piec
# difficulti
# understand
# cours
# opinion
# podcast
# enough
# would
# prefer
# video
# watch
# becaus
# visual
# bring
# better
# understand
# mayb
# while
# audio
# clear
# understand
# present
# bore
# manner
# listen
# focu
# insuffici
# evid
# clearli
# depend
# person
# willing
# improv
# scienc
# commun
# skill
# content
# engag
# unfortun
# educ
# system
# place
# emphasi
# learn
# grade
# understand
# practic
# applic
# ...

# %%
import nltk
from nltk import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lisaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
wordsay= word_tokenize(ayes)
wordsan= word_tokenize(ano)
wordsad= word_tokenize(adontknow)
wordsby= word_tokenize(byes)
wordsbn= word_tokenize(bno)
wordsbd= word_tokenize(bdontknow)

# %%
v=[]
for m in wordsay: 
    if len(m) > 4: 
        v.append(m)
fdist= FreqDist(v)

ayesr=fdist.most_common(20)
ayesr

wordcloud = WordCloud().generate(str(ayesr))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
v1=[]
for m in wordsan: 
    if len(m) > 4: 
        v1.append(m)
fdist1= FreqDist(v1)
fdist1

ayesr=fdist.most_common(20)
ayesr

wordcloud = WordCloud().generate(str(ayesr))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# FreqDist({'person': 1, 'monotone': 1, 'could': 1, 'follow': 1, 'along': 1, 'after': 1, 'minutes': 1})

# %%
v2=[]
for m in wordsad: 
    if len(m) > 4: 
        v2.append(m)
fdist2= FreqDist(v2)
fdist2

ayesr=fdist.most_common(20)
ayesr

wordcloud = WordCloud().generate(str(ayesr))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# FreqDist({'explanation': 1, 'seems': 1, 'scientifically': 1, 'correct': 1, 'would': 1, 'drawing': 1, 'written': 1, 'truly': 1, 'understand': 1, 'think': 1, ...})

# %%
v3=[]
for m in wordsby: 
    if len(m) > 4: 
        v3.append(m)
fdist3= FreqDist(v3)
fdist3

ayesr=fdist.most_common(20)
ayesr

wordcloud = WordCloud().generate(str(ayesr))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# FreqDist({'podcast': 3, 'visual': 3, 'would': 2, 'person': 2, 'communication': 2, 'class': 2, 'physics': 2, 'enough': 2, 'clear': 2, 'depends': 1, ...})

# %%
v4=[]
for m in wordsbn: 
    if len(m) > 4: 
        v4.append(m)
fdist4= FreqDist(v4)
fdist4
ayesr=fdist.most_common(20)
ayesr

wordcloud = WordCloud().generate(str(ayesr))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# FreqDist({'explanation': 1, 'seems': 1, 'scientifically': 1, 'correct': 1, 'would': 1, 'drawing': 1, 'written': 1, 'truly': 1, 'understand': 1, 'think': 1, ...})

# %%
v5=[]
for m in wordsbd: 
    if len(m) > 4: 
        v5.append(m)
fdist5= FreqDist(v5)
fdist5
ayesr=fdist.most_common(20)
ayesr

wordcloud = WordCloud().generate(str(ayesr))
plt.imshow(wordcloud)

plt.axis('off')
# Out:
# FreqDist({'audio': 3, 'podcast': 3, 'person': 3, 'enough': 3, 'understanding': 3, 'quite': 2, 'listen': 2, 'visual': 2, 'understand': 2, 'communication': 2, ...})
